# %%
#Prophet Model [scrape_duration_seconds]

import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('/content/scrape_duration_seconds.csv')
final_df = df

# Rename columns to fit Prophet's requirements
df.rename(columns={'Time': 'ds', 'Value': 'y'}, inplace=True)

# Convert the 'ds' column to datetime
df['ds'] = pd.to_datetime(df['ds'])

# Initialize and fit the Prophet model
model = Prophet()
model.fit(df[['ds', 'y']])

# Make a future dataframe for prediction (let's predict 100 steps ahead)
future = model.make_future_dataframe(periods=100, freq='15s')  # Assuming 15-second intervals in the data
forecast = model.predict(future)

# Plot the forecast
fig = model.plot(forecast)

# Add anomaly detection (optional)
df['yhat'] = forecast['yhat'][:len(df)]
df['yhat_upper'] = forecast['yhat_upper'][:len(df)]
df['yhat_lower'] = forecast['yhat_lower'][:len(df)]

# Anomalies are when the actual value falls outside the prediction interval
anomalies = df[(df['y'] > df['yhat_upper']) | (df['y'] < df['yhat_lower'])]

# Plot anomalies
plt.scatter(anomalies['ds'], anomalies['y'], color='red', label='Anomalies')
plt.legend()

# Show the plot
plt.show()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/pt82aagl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/bf1s2k6d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1552', 'data', 'file=/tmp/tmp74v04202/pt82aagl.json', 'init=/tmp/tmp74v04202/bf1s2k6d.json', 'output', 'file=/tmp/tmp74v04202/prophet_modelru1dekcd/prophet_model-20240830091639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:16:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:16:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
#Prophet Model [duration_milliseconds_count]

import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('/content/duration_milliseconds_count.csv')
final_df = df

# Rename columns to fit Prophet's requirements
df.rename(columns={'Time': 'ds', 'Value': 'y'}, inplace=True)

# Convert the 'ds' column to datetime
df['ds'] = pd.to_datetime(df['ds'])

# Initialize and fit the Prophet model
model = Prophet()
model.fit(df[['ds', 'y']])

# Make a future dataframe for prediction (let's predict 100 steps ahead)
future = model.make_future_dataframe(periods=100, freq='15s')  # Assuming 15-second intervals in the data
forecast = model.predict(future)

# Plot the forecast
fig = model.plot(forecast)

# Add anomaly detection (optional)
df['yhat'] = forecast['yhat'][:len(df)]
df['yhat_upper'] = forecast['yhat_upper'][:len(df)]
df['yhat_lower'] = forecast['yhat_lower'][:len(df)]

# Anomalies are when the actual value falls outside the prediction interval
anomalies = df[(df['y'] > df['yhat_upper']) | (df['y'] < df['yhat_lower'])]

# Plot anomalies
plt.scatter(anomalies['ds'], anomalies['y'], color='red', label='Anomalies')
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-49-710c502d85b1>:8: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/duration_milliseconds_count.csv')
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/c6m3j8pe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/eflwmpdp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9653', 'data', 'file=/tmp/tmp74v04202/c6m3j8pe.json', 'init=/tmp/tmp74v04202/eflwmpdp.json', 'output', 'file=/tmp/tmp74v04202/prophet_model3n5auiob/prophet_model-20240830091703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:17:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:17:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
#Prophet Model [duration_milliseconds_sum]

import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('/content/duration_milliseconds_sum.csv')
final_df = df

# Rename columns to fit Prophet's requirements
df.rename(columns={'Time': 'ds', 'Value': 'y'}, inplace=True)

# Convert the 'ds' column to datetime
df['ds'] = pd.to_datetime(df['ds'])

# Initialize and fit the Prophet model
model = Prophet()
model.fit(df[['ds', 'y']])

# Make a future dataframe for prediction (let's predict 100 steps ahead)
future = model.make_future_dataframe(periods=100, freq='15s')  # Assuming 15-second intervals in the data
forecast = model.predict(future)

# Plot the forecast
fig = model.plot(forecast)

# Add anomaly detection (optional)
df['yhat'] = forecast['yhat'][:len(df)]
df['yhat_upper'] = forecast['yhat_upper'][:len(df)]
df['yhat_lower'] = forecast['yhat_lower'][:len(df)]

# Anomalies are when the actual value falls outside the prediction interval
anomalies = df[(df['y'] > df['yhat_upper']) | (df['y'] < df['yhat_lower'])]

# Plot anomalies
plt.scatter(anomalies['ds'], anomalies['y'], color='red', label='Anomalies')
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-50-5862e6f406ba>:8: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/duration_milliseconds_sum.csv')
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/q2xd3ear.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/dtsg7rxu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48888', 'data', 'file=/tmp/tmp74v04202/q2xd3ear.json', 'init=/tmp/tmp74v04202/dtsg7rxu.json', 'output', 'file=/tmp/tmp74v04202/prophet_model8exv_dmc/prophet_model-20240830091731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:17:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:17:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
#Prophet Model [calls_total]

import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('/content/calls_total.csv')
final_df = df

# Rename columns to fit Prophet's requirements
df.rename(columns={'Time': 'ds', 'Value': 'y'}, inplace=True)

# Convert the 'ds' column to datetime
df['ds'] = pd.to_datetime(df['ds'])

# Initialize and fit the Prophet model
model = Prophet()
model.fit(df[['ds', 'y']])

# Make a future dataframe for prediction (let's predict 100 steps ahead)
future = model.make_future_dataframe(periods=100, freq='15s')  # Assuming 15-second intervals in the data
forecast = model.predict(future)

# Plot the forecast
fig = model.plot(forecast)

# Add anomaly detection (optional)
df['yhat'] = forecast['yhat'][:len(df)]
df['yhat_upper'] = forecast['yhat_upper'][:len(df)]
df['yhat_lower'] = forecast['yhat_lower'][:len(df)]

# Anomalies are when the actual value falls outside the prediction interval
anomalies = df[(df['y'] > df['yhat_upper']) | (df['y'] < df['yhat_lower'])]

# Plot anomalies
plt.scatter(anomalies['ds'], anomalies['y'], color='red', label='Anomalies')
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-51-d8d9f4e92ec7>:8: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/calls_total.csv')
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/60paxg3f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/kj2jghxq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39533', 'data', 'file=/tmp/tmp74v04202/60paxg3f.json', 'init=/tmp/tmp74v04202/kj2jghxq.json', 'output', 'file=/tmp/tmp74v04202/prophet_modelizmi86ca/prophet_model-20240830091752.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:17:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:18:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
#Prophet Model [calls_total]

import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('/content/duration_milliseconds_bucket.csv')
final_df = df

# Rename columns to fit Prophet's requirements
df.rename(columns={'Time': 'ds', 'Value': 'y'}, inplace=True)

# Convert the 'ds' column to datetime
df['ds'] = pd.to_datetime(df['ds'])

# Initialize and fit the Prophet model
model = Prophet()
model.fit(df[['ds', 'y']])

# Make a future dataframe for prediction (let's predict 100 steps ahead)
future = model.make_future_dataframe(periods=100, freq='15s')  # Assuming 15-second intervals in the data
forecast = model.predict(future)

# Plot the forecast
fig = model.plot(forecast)

# Add anomaly detection (optional)
df['yhat'] = forecast['yhat'][:len(df)]
df['yhat_upper'] = forecast['yhat_upper'][:len(df)]
df['yhat_lower'] = forecast['yhat_lower'][:len(df)]

# Anomalies are when the actual value falls outside the prediction interval
anomalies = df[(df['y'] > df['yhat_upper']) | (df['y'] < df['yhat_lower'])]

# Plot anomalies
plt.scatter(anomalies['ds'], anomalies['y'], color='red', label='Anomalies')
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-52-62046bdb682d>:8: DtypeWarning: Columns (2,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/duration_milliseconds_bucket.csv')
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/kdghurk0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp74v04202/i1r55ujo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40884', 'data', 'file=/tmp/tmp74v04202/kdghurk0.json', 'init=/tmp/tmp74v04202/i1r55ujo.json', 'output', 'file=/tmp/tmp74v04202/prophet_model_oz7_kye/prophet_model-20240830091925.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:19:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:23:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',
